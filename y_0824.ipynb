# %%
import numpy as np
import pandas as pd
from pathlib import Path

import os

# %%
income_dir = './income'
income_list = os.listdir(income_dir)
pd.DataFrame(income_list)
# Out:
#                                 0
# 0               0.1인당_GRDP_시도.csv
# 1  1.월평균_임금_및_임금상승률_시도(11~20).csv
# 2         2.소비자물가지수_시도(11~20).csv

# %%
pop_dir = './pop'
pop_list = os.listdir(pop_dir)
pd.DataFrame(pop_list)
# Out:
#                          0
# 0  0.인구총조사_인구_시도_시_군_구.csv
# 1       1.총조사인구_총괄_시군구.csv
# 2       2.시도별_1인당_grdp.csv
# 3     3.시군구별 인구(05_19).csv
# 4     4.인구증가율_시도_시_군_구.csv
# 5    5.전입,전출(16_20,연별).csv
# 6  6.중위연령, 평균연령(00_19).csv

# %%
df2 = pd.read_csv(os.path.join(pop_dir, pop_list[3]), encoding='CP949')
df2
# Out:
#      소재지(시군구)별               인구현황별              항목   단위       2005 년  \
# 0           전국             전체인구(A)  도시지역 인구현황(시군구)    명  48782274.00
# 1           전국             도시인구(B)  도시지역 인구현황(시군구)  NaN  43959922.00
# 2           전국        비도시인구(C=A-B)  도시지역 인구현황(시군구)  NaN   4822352.00
# 3           전국             도시인구(D)  도시지역 인구현황(시군구)  NaN  43445493.00
# 4           전국         농촌인구(E=A-D)  도시지역 인구현황(시군구)  NaN   5336781.00
# ...        ...                 ...             ...  ...          ...
# 1899      남제주군        비도시인구(C=A-B)  도시지역 인구현황(시군구)  NaN     27475.00
# 1900      남제주군             도시인구(D)  도시지역 인구현황(시군구)  NaN     52324.00
# 1901      남제주군         농촌인구(E=A-D)  도시지역 인구현황(시군구)  NaN     21517.00
# 1902      남제주군  용도지역 인구기준(B/A*100)  도시지역 인구현황(시군구)  NaN        62.79
# 1903      남제주군  행정구역 인구기준(D/A*100)  도시지역 인구현황(시군구)  NaN        70.86
#
#           2006 년      2007 년      2008 년      2009 년      2010 년      2011 년  \
# ...

# %%
df = pd.read_csv(os.path.join(income_dir, income_list[1]), encoding='CP949')
df.head()
# Out:
#    행정구역별(1)           2011           2012     2012.1           2013  \
# 0  행정구역별(1)  상용 월평균 임금 (원)  상용 월평균 임금 (원)  임금상승률 (%)  상용 월평균 임금 (원)
# 1        전국        2487339        2619833        5.3        2736921
# 2     서울특별시        2921496        3007110        2.9        3168798
# 3     부산광역시        2356022        2453216        4.1        2520222
# 4     대구광역시        2165156        2263709        4.6        2315945
#
#       2013.1           2014     2014.1           2015     2015.1  \
# 0  임금상승률 (%)  상용 월평균 임금 (원)  임금상승률 (%)  상용 월평균 임금 (원)  임금상승률 (%)
# 1        4.5        2838343        3.7        2926186        3.1
# 2        5.4        3199814        1.0        3261561        1.9
# 3        2.7        2558970        1.5        2620611        2.4
# 4        2.3        2352273        1.6        2415995        2.7
#
#             2016     2016.1           2017     2017.1           2018  \
# 0  상용 월평균 임금 (원)  임금상승률 (%)  상용 월평균 임금 (원)  임금상승률 (%)  상용 월평균 임금 (원)
# ...

# %%
df['2011.1'] = 0
df.loc[0,'2011.1'] = '임금상승률 (%)'

# %%
df.columns
# Out:
# Index(['행정구역별(1)', '2011', '2012', '2012.1', '2013', '2013.1', '2014',
#        '2014.1', '2015', '2015.1', '2016', '2016.1', '2017', '2017.1', '2018',
#        '2018.1', '2019', '2019.1', '2020', '2020.1', '2011.1'],
#       dtype='object')

# %%
df = df[['행정구역별(1)', '2011', '2011.1', '2012', '2012.1', '2013', '2013.1', '2014',
       '2014.1', '2015', '2015.1', '2016', '2016.1', '2017', '2017.1', '2018',
       '2018.1', '2019', '2019.1', '2020', '2020.1']]

# %%
df
# Out:
#     행정구역별(1)           2011     2011.1           2012     2012.1  \
# 0   행정구역별(1)  상용 월평균 임금 (원)  임금상승률 (%)  상용 월평균 임금 (원)  임금상승률 (%)
# 1         전국        2487339          0        2619833        5.3
# 2      서울특별시        2921496          0        3007110        2.9
# 3      부산광역시        2356022          0        2453216        4.1
# 4      대구광역시        2165156          0        2263709        4.6
# 5      인천광역시        2410840          0        2508165        4.0
# 6      광주광역시        2226364          0        2319070        4.2
# 7      대전광역시        2487288          0        2642595        6.2
# 8      울산광역시        2822173          0        2936723        4.1
# 9    세종특별자치시              -          0              -          -
# 10       경기도        2467899          0        2654114        7.5
# 11       강원도        2242956          0        2360819        5.3
# 12      충청북도        2299646          0        2409021        4.8
# ...

# %%
## 첫번째 행, 세종시 행 삭제

df.drop(index = [0,9], inplace = True)
df = df.reset_index(drop=True)

# %%
df
# Out:
#    행정구역별(1)     2011 2011.1     2012 2012.1     2013 2013.1     2014 2014.1  \
# 0        전국  2487339      0  2619833    5.3  2736921    4.5  2838343    3.7
# 1     서울특별시  2921496      0  3007110    2.9  3168798    5.4  3199814    1.0
# 2     부산광역시  2356022      0  2453216    4.1  2520222    2.7  2558970    1.5
# 3     대구광역시  2165156      0  2263709    4.6  2315945    2.3  2352273    1.6
# 4     인천광역시  2410840      0  2508165    4.0  2609457    4.0  2637047    1.1
# 5     광주광역시  2226364      0  2319070    4.2  2417477    4.2  2493312    3.1
# 6     대전광역시  2487288      0  2642595    6.2  2722674    3.0  2805150    3.0
# 7     울산광역시  2822173      0  2936723    4.1  2834007   -3.5  2952210    4.2
# 8       경기도  2467899      0  2654114    7.5  2735767    3.1  2784899    1.8
# 9       강원도  2242956      0  2360819    5.3  2437051    3.2  2483529    1.9
# 10     충청북도  2299646      0  2409021    4.8  2513146    4.3  2535148    0.9
# ...

# %%
## 임금인상률만 남겨서 df1_1 만듦
for i in range(2011,2021):
    df.drop(columns = '{}'.format(i),inplace = True)
    df_1 = df
df_1
# Out:
#    행정구역별(1) 2011.1 2012.1 2013.1 2014.1 2015.1 2016.1 2017.1 2018.1 2019.1  \
# 0        전국      0    5.3    4.5    3.7    3.1    3.6    3.1    4.3    4.5
# 1     서울특별시      0    2.9    5.4    1.0    1.9    3.2    2.4    3.4    3.9
# 2     부산광역시      0    4.1    2.7    1.5    2.4    2.8    3.4    6.3    3.0
# 3     대구광역시      0    4.6    2.3    1.6    2.7    2.3    6.5    5.0    5.1
# 4     인천광역시      0    4.0    4.0    1.1    3.3    4.3    2.6    3.4    3.6
# 5     광주광역시      0    4.2    4.2    3.1    2.8    2.7    3.8    2.6    5.0
# 6     대전광역시      0    6.2    3.0    3.0    1.9    4.5    2.9    3.8    3.0
# 7     울산광역시      0    4.1   -3.5    4.2    4.5    1.2    1.5    3.4    3.0
# 8       경기도      0    7.5    3.1    1.8    2.5    4.1    4.4    4.3    4.6
# 9       강원도      0    5.3    3.2    1.9    3.4    6.2    2.8    4.5    4.0
# 10     충청북도      0    4.8    4.3    0.9    3.8    5.4    4.1    5.1    3.5
# ...

# %%
df1 = pd.read_csv(os.path.join(data_dir, data_list[2]), encoding='CP949')
df1.drop(columns = ['시도별(1)','품목별(1)'],inplace = True)
df1.head()
# Out:
#   시도별(2)    2011    2012    2013    2014   2015    2016    2017    2018  \
# 0     소계  94.717  96.789  98.048  99.298  100.0  100.97  102.93  104.45
# 1  서울특별시  93.586  95.908  97.245  98.761  100.0  101.18  103.20  104.58
# 2  부산광역시  94.258  96.514  97.938  99.168  100.0  101.18  102.99  104.78
# 3  대구광역시  93.967  96.268  97.859  99.263  100.0  101.00  103.06  104.85
# 4  인천광역시  94.723  96.602  97.648  99.018  100.0  100.85  102.77  104.43
#
#      2019    2020
# 0  104.85  105.42
# 1  105.20  105.85
# 2  105.29  105.48
# 3  105.55  105.86
# 4  104.71  105.53

# %%
df1_1 = pd.DataFrame()

for i in np.arange(2011,2020):
    df1_1['{}'.format(i+1)] = df1['{}'.format(i+1)] - df1['{}'.format(i)]
df1_1['2011'] = 0
df1_1
# Out:
#      2012   2013   2014   2015  2016  2017  2018  2019  2020  2011
# 0   2.072  1.259  1.250  0.702  0.97  1.96  1.52  0.40  0.57     0
# 1   2.322  1.337  1.516  1.239  1.18  2.02  1.38  0.62  0.65     0
# 2   2.256  1.424  1.230  0.832  1.18  1.81  1.79  0.51  0.19     0
# 3   2.301  1.591  1.404  0.737  1.00  2.06  1.79  0.70  0.31     0
# 4   1.879  1.046  1.370  0.982  0.85  1.92  1.66  0.28  0.82     0
# 5   1.701  1.252  1.575  0.277  0.92  2.11  1.21  0.23  0.46     0
# 6   1.915  0.966  0.906  0.198  0.68  1.67  1.58  0.22  0.40     0
# 7   2.036  1.470  1.168  0.457  0.99  1.87  1.06 -0.33  0.30     0
# 8   2.004  1.183  1.212  0.734  0.94  2.03  1.53  0.42  0.64     0
# 9   1.863  1.066  0.675  0.036  0.79  2.01  1.64  0.88  0.65     0
# 10  1.883  1.226  1.175 -0.154  0.57  2.01  1.68  0.38  0.54     0
# 11  2.296  1.166  0.463  0.216  0.69  1.95  1.47 -0.10  0.69     0
# 12  2.085  1.179  1.113 -0.029  0.54  1.86  1.75  0.33  0.56     0
# ...

# %%
df1_1.columns
# Out:
# Index(['2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020',
#        '2011'],
#       dtype='object')

# %%
df1_1 = df1_1[['2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020']]

# %%
df1_1
# Out:
#     2011   2012   2013   2014   2015  2016  2017  2018  2019  2020
# 0      0  2.072  1.259  1.250  0.702  0.97  1.96  1.52  0.40  0.57
# 1      0  2.322  1.337  1.516  1.239  1.18  2.02  1.38  0.62  0.65
# 2      0  2.256  1.424  1.230  0.832  1.18  1.81  1.79  0.51  0.19
# 3      0  2.301  1.591  1.404  0.737  1.00  2.06  1.79  0.70  0.31
# 4      0  1.879  1.046  1.370  0.982  0.85  1.92  1.66  0.28  0.82
# 5      0  1.701  1.252  1.575  0.277  0.92  2.11  1.21  0.23  0.46
# 6      0  1.915  0.966  0.906  0.198  0.68  1.67  1.58  0.22  0.40
# 7      0  2.036  1.470  1.168  0.457  0.99  1.87  1.06 -0.33  0.30
# 8      0  2.004  1.183  1.212  0.734  0.94  2.03  1.53  0.42  0.64
# 9      0  1.863  1.066  0.675  0.036  0.79  2.01  1.64  0.88  0.65
# 10     0  1.883  1.226  1.175 -0.154  0.57  2.01  1.68  0.38  0.54
# 11     0  2.296  1.166  0.463  0.216  0.69  1.95  1.47 -0.10  0.69
# 12     0  2.085  1.179  1.113 -0.029  0.54  1.86  1.75  0.33  0.56
# ...

# %%
from matplotlib.patches import Rectangle
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors

def plot_colortable(colors, title, sort_colors=True, emptycols=0):

    cell_width = 212
    cell_height = 22
    swatch_width = 48
    margin = 12
    topmargin = 40

    # Sort colors by hue, saturation, value and name.
    if sort_colors is True:
        by_hsv = sorted((tuple(mcolors.rgb_to_hsv(mcolors.to_rgb(color))),
                         name)
                        for name, color in colors.items())
        names = [name for hsv, name in by_hsv]
    else:
        names = list(colors)

    n = len(names)
    ncols = 4 - emptycols
    nrows = n // ncols + int(n % ncols > 0)

    width = cell_width * 4 + 2 * margin
    height = cell_height * nrows + margin + topmargin
    dpi = 72

    fig, ax = plt.subplots(figsize=(width / dpi, height / dpi), dpi=dpi)
    fig.subplots_adjust(margin/width, margin/height,
                        (width-margin)/width, (height-topmargin)/height)
    ax.set_xlim(0, cell_width * 4)
    ax.set_ylim(cell_height * (nrows-0.5), -cell_height/2.)
    ax.yaxis.set_visible(False)
    ax.xaxis.set_visible(False)
    ax.set_axis_off()
    ax.set_title(title, fontsize=24, loc="left", pad=10)

    for i, name in enumerate(names):
        row = i % nrows
        col = i // nrows
        y = row * cell_height

        swatch_start_x = cell_width * col
        text_pos_x = cell_width * col + swatch_width + 7

        ax.text(text_pos_x, y, name, fontsize=14,
                horizontalalignment='left',
                verticalalignment='center')

        ax.add_patch(
            Rectangle(xy=(swatch_start_x, y-9), width=swatch_width,
                      height=18, facecolor=colors[name])
        )

    return fig

# plot_colortable(mcolors.BASE_COLORS, "Base Colors",
#                 sort_colors=False, emptycols=1)
# plot_colortable(mcolors.TABLEAU_COLORS, "Tableau Palette",
#                 sort_colors=False, emptycols=2)

# plot_colortable(mcolors.CSS4_COLORS, "CSS Colors")

# %%
## 임금상승률

plt.rc('font', size = 15, family='Malgun Gothic')
plt.rcParams['axes.unicode_minus'] = False
plt.figure(figsize=(15,10))

colors = list(mcolors.CSS4_COLORS.keys())
import random 
random.shuffle(colors) 

plt.figure(figsize=(15,10))
for i in range(0, 16):
    plt.plot(df_1.columns[1:], df_1.iloc[i, 1:].astype('float'), 
             marker = 'o',
             linewidth = 3,
             label=df.iloc[i, 0], 
             color=colors[i],
            )
plt.legend()

# %%
## 물가상승률

# plt.figure(figsize=(15,10))
# for i in range(0, 16):
#     plt.plot(df1.columns[1:], df1.iloc[i, 1:].astype('float'), 
#              marker = 'o',
#              linewidth = 3,
#              label=df.iloc[i, 0], 
#              color=colors[i],
#             )
# plt.legend()

plt.figure(figsize=(15,10))
for i in range(0, 16):
    plt.plot(df1_1.columns[0:], df1_1.iloc[i, 0:].astype('float'), 
             marker = 'o',
             linewidth = 3,
             label=df.iloc[i, 0], 
             color=colors[i],
            )
plt.legend()

# %%
df_1.iloc[:,0]
# Out:
# 0          전국
# 1       서울특별시
# 2       부산광역시
# 3       대구광역시
# 4       인천광역시
# 5       광주광역시
# 6       대전광역시
# 7       울산광역시
# 8         경기도
# 9         강원도
# 10       충청북도
# 11       충청남도
# 12       전라북도
# 13       전라남도
# 14       경상북도
# 15       경상남도
# 16    제주특별자치도
# Name: 행정구역별(1), dtype: object

# %%
colors=['#090707', '#E53A40', '#EFDC05', '#30A9DE', '#A593E0', '#E0E3DA', 
       '#566270', '#F6B352', '#8CD790', '#77AF9C', '#285943', '#58C9B9', 
        '#D499B9', '#f9c00c', '#00b9f1', '#7200da', '#a79c8e', '#cbe86b']

# %%
plt.figure(figsize=(15,10))

index = 1

xlabels = list(df1_1.columns)

plt.plot(xlabels, df_1.iloc[index, 1:].astype('float'), 
             marker = 'o',
             linewidth = 3,
             label='임금인상률', 
             color='tab:blue',
            )
plt.plot(xlabels, df1_1.iloc[index, :].astype('float'), 
             marker = 'o',
             linewidth = 3,
             label='물가상승률', 
             color='#E53A40',
            )
plt.legend()
plt.grid()
