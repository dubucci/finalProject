# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc
font_path = "C:/Windows/Fonts/NGULIM.TTF"
font = font_manager.FontProperties(fname=font_path).get_name()
rc('font', family=font)

# %%
plt.style.use('fivethirtyeight')

# %%
data_dir = './pop/'
data_list = os.listdir(data_dir)
df = pd.read_csv(os.path.join(data_dir + data_list[0]), encoding='cp949')

# %%
df2 = pd.read_csv(os.path.join(data_dir + data_list[1]), encoding='cp949')
for year in range(1970, 2015, 5):
    df2 = df2.drop(columns=['{}.1'.format(year)], axis=1)
df2 = df2.drop(columns='연령별', axis=1)

# %%
df2 = df2.drop([0, 2], axis=0)
df2
# Out:
#     행정구역별      1970      1975      1980      1985      1990      1995  \
# 1      전국  31435252  34678972  37406815  40419652  43390374  44553710
# 3   서울특별시   5525262   6879464   8350616   9625755  10603250  10217177
# 4   부산광역시   1876391   2450125   3156931   3512113   3795892   3809618
# 5   대구광역시         -         -         -   2028370   2227979   2445288
# 6   인천광역시         -         -         -   1384916   1816328   2304176
# 7   광주광역시         -         -         -         -   1138717   1257063
# 8   대전광역시         -         -         -         -   1049122   1270873
# 9   울산광역시         -         -         -         -         -         -
# 10    경기도   3353272   4034707   4930335   4792617   6154359   7637942
# 11    강원도   1865426   1860768   1790226   1724146   1579859   1465279
# 12   충청북도   1480338   1521348   1423381   1390326   1389222   1395460
# 13   충청남도   2858202   2947023   2954662   2999837   2013270   1765021
# 14   전라북도   2431892   2455093   2286720   2201265   2069378   1900558
# 15   전라남도   4004832   3982752   3778777   3747506   2506944   2066109
# 16   경상북도   4555866   4855852   4952012   3010001   2860109   2672498
# 17   경상남도   3118634   3278718   3320546   3514500   3671509   3841553
# 18    제주도    365137    411486    462609    488300    514436    505095
#
#         2000      2005      2010
# 1   45985289  47041434  47990761
# 3    9853972   9762546   9631482
# 4    3655437   3512547   3393191
# 5    2473990   2456016   2431774
# 6    2466338   2517680   2632035
# 7    1350948   1413644   1466143
# 8    1365961   1438551   1490158
# 9    1012110   1044934   1071673
# 10   8937752  10341006  11196053
# 11   1484536   1460770   1463650
# 12   1462621   1453872   1495984
# 13   1840410   1879417   2000473
# 14   1887239   1778879   1766044
# 15   1994287   1815174   1728749
# 16   2716218   2594719   2575370
# 17   2970929   3040993   3119571
# 18    512541    530686    528411

# %%
df2 = df2.reset_index().drop(columns='index')
df2
# Out:
#     행정구역별      1970      1975      1980      1985      1990      1995  \
# 0      전국  31435252  34678972  37406815  40419652  43390374  44553710
# 1   서울특별시   5525262   6879464   8350616   9625755  10603250  10217177
# 2   부산광역시   1876391   2450125   3156931   3512113   3795892   3809618
# 3   대구광역시         -         -         -   2028370   2227979   2445288
# 4   인천광역시         -         -         -   1384916   1816328   2304176
# 5   광주광역시         -         -         -         -   1138717   1257063
# 6   대전광역시         -         -         -         -   1049122   1270873
# 7   울산광역시         -         -         -         -         -         -
# 8     경기도   3353272   4034707   4930335   4792617   6154359   7637942
# 9     강원도   1865426   1860768   1790226   1724146   1579859   1465279
# 10   충청북도   1480338   1521348   1423381   1390326   1389222   1395460
# 11   충청남도   2858202   2947023   2954662   2999837   2013270   1765021
# 12   전라북도   2431892   2455093   2286720   2201265   2069378   1900558
# 13   전라남도   4004832   3982752   3778777   3747506   2506944   2066109
# 14   경상북도   4555866   4855852   4952012   3010001   2860109   2672498
# 15   경상남도   3118634   3278718   3320546   3514500   3671509   3841553
# 16    제주도    365137    411486    462609    488300    514436    505095
#
#         2000      2005      2010
# 0   45985289  47041434  47990761
# 1    9853972   9762546   9631482
# 2    3655437   3512547   3393191
# 3    2473990   2456016   2431774
# 4    2466338   2517680   2632035
# 5    1350948   1413644   1466143
# 6    1365961   1438551   1490158
# 7    1012110   1044934   1071673
# 8    8937752  10341006  11196053
# 9    1484536   1460770   1463650
# 10   1462621   1453872   1495984
# 11   1840410   1879417   2000473
# 12   1887239   1778879   1766044
# 13   1994287   1815174   1728749
# 14   2716218   2594719   2575370
# 15   2970929   3040993   3119571
# 16    512541    530686    528411

# %%
df2.iloc[0,0]
# Out:
# '전국'

# %%
df2 = df2.replace('-', 0)

# %%
df2
# Out:
#     행정구역별      1970      1975      1980      1985      1990      1995  \
# 0      전국  31435252  34678972  37406815  40419652  43390374  44553710
# 1   서울특별시   5525262   6879464   8350616   9625755  10603250  10217177
# 2   부산광역시   1876391   2450125   3156931   3512113   3795892   3809618
# 3   대구광역시         0         0         0   2028370   2227979   2445288
# 4   인천광역시         0         0         0   1384916   1816328   2304176
# 5   광주광역시         0         0         0         0   1138717   1257063
# 6   대전광역시         0         0         0         0   1049122   1270873
# 7   울산광역시         0         0         0         0         0         0
# 8     경기도   3353272   4034707   4930335   4792617   6154359   7637942
# 9     강원도   1865426   1860768   1790226   1724146   1579859   1465279
# 10   충청북도   1480338   1521348   1423381   1390326   1389222   1395460
# 11   충청남도   2858202   2947023   2954662   2999837   2013270   1765021
# 12   전라북도   2431892   2455093   2286720   2201265   2069378   1900558
# 13   전라남도   4004832   3982752   3778777   3747506   2506944   2066109
# 14   경상북도   4555866   4855852   4952012   3010001   2860109   2672498
# 15   경상남도   3118634   3278718   3320546   3514500   3671509   3841553
# 16    제주도    365137    411486    462609    488300    514436    505095
#
#         2000      2005      2010
# 0   45985289  47041434  47990761
# 1    9853972   9762546   9631482
# 2    3655437   3512547   3393191
# 3    2473990   2456016   2431774
# 4    2466338   2517680   2632035
# 5    1350948   1413644   1466143
# 6    1365961   1438551   1490158
# 7    1012110   1044934   1071673
# 8    8937752  10341006  11196053
# 9    1484536   1460770   1463650
# 10   1462621   1453872   1495984
# 11   1840410   1879417   2000473
# 12   1887239   1778879   1766044
# 13   1994287   1815174   1728749
# 14   2716218   2594719   2575370
# 15   2970929   3040993   3119571
# 16    512541    530686    528411

# %%
from matplotlib.patches import Rectangle
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors

def plot_colortable(colors, title, sort_colors=True, emptycols=0):

    cell_width = 212
    cell_height = 22
    swatch_width = 48
    margin = 12
    topmargin = 40

    # Sort colors by hue, saturation, value and name.
    if sort_colors is True:
        by_hsv = sorted((tuple(mcolors.rgb_to_hsv(mcolors.to_rgb(color))),
                         name)
                        for name, color in colors.items())
        names = [name for hsv, name in by_hsv]
    else:
        names = list(colors)

    n = len(names)
    ncols = 4 - emptycols
    nrows = n // ncols + int(n % ncols > 0)

    width = cell_width * 4 + 2 * margin
    height = cell_height * nrows + margin + topmargin
    dpi = 72

    fig, ax = plt.subplots(figsize=(width / dpi, height / dpi), dpi=dpi)
    fig.subplots_adjust(margin/width, margin/height,
                        (width-margin)/width, (height-topmargin)/height)
    ax.set_xlim(0, cell_width * 4)
    ax.set_ylim(cell_height * (nrows-0.5), -cell_height/2.)
    ax.yaxis.set_visible(False)
    ax.xaxis.set_visible(False)
    ax.set_axis_off()
    ax.set_title(title, fontsize=24, loc="left", pad=10)

    for i, name in enumerate(names):
        row = i % nrows
        col = i // nrows
        y = row * cell_height

        swatch_start_x = cell_width * col
        text_pos_x = cell_width * col + swatch_width + 7

        ax.text(text_pos_x, y, name, fontsize=14,
                horizontalalignment='left',
                verticalalignment='center')

        ax.add_patch(
            Rectangle(xy=(swatch_start_x, y-9), width=swatch_width,
                      height=18, facecolor=colors[name])
        )

    return fig

plot_colortable(mcolors.BASE_COLORS, "Base Colors",
                sort_colors=False, emptycols=1)
plot_colortable(mcolors.TABLEAU_COLORS, "Tableau Palette",
                sort_colors=False, emptycols=2)

plot_colortable(mcolors.CSS4_COLORS, "CSS Colors")

# %%
# x = 연도
# y = 연도별 인구수
colors = list(mcolors.CSS4_COLORS.keys())
import random 
random.shuffle(colors) 

plt.figure(figsize=(15,10))
for i in range(1, 17):
    plt.plot(df2.columns[1:], df2.iloc[i, 1:].astype('float'), 
             label=df2.iloc[i, 0], 
             color=colors[i],
            )
plt.legend()

# %%
plt.plot(df2.columns[1:], df2.iloc[0, 1:].astype('float'),label=str(df.iloc[0, 0]))

# %% [markdown]
# ## df+df2 합치기

# %%
df = df.drop([1, 2, 3], axis=0).reset_index()
df = df.drop(columns='index')

# %%
df = df.drop(columns=['2016', '2017', '2018', '2019'])

# %%
df2.loc[17, '행정구역별'] = '세종특별자치시'

# %%
df2
# Out:
#       행정구역별      1970      1975      1980      1985      1990      1995  \
# 0        전국  31435252  34678972  37406815  40419652  43390374  44553710
# 1     서울특별시   5525262   6879464   8350616   9625755  10603250  10217177
# 2     부산광역시   1876391   2450125   3156931   3512113   3795892   3809618
# 3     대구광역시         0         0         0   2028370   2227979   2445288
# 4     인천광역시         0         0         0   1384916   1816328   2304176
# 5     광주광역시         0         0         0         0   1138717   1257063
# 6     대전광역시         0         0         0         0   1049122   1270873
# 7     울산광역시         0         0         0         0         0         0
# 8       경기도   3353272   4034707   4930335   4792617   6154359   7637942
# 9       강원도   1865426   1860768   1790226   1724146   1579859   1465279
# 10     충청북도   1480338   1521348   1423381   1390326   1389222   1395460
# 11     충청남도   2858202   2947023   2954662   2999837   2013270   1765021
# 12     전라북도   2431892   2455093   2286720   2201265   2069378   1900558
# 13     전라남도   4004832   3982752   3778777   3747506   2506944   2066109
# 14     경상북도   4555866   4855852   4952012   3010001   2860109   2672498
# 15     경상남도   3118634   3278718   3320546   3514500   3671509   3841553
# 16      제주도    365137    411486    462609    488300    514436    505095
# 17  세종특별자치시       NaN       NaN       NaN       NaN       NaN       NaN
#
#         2000      2005      2010
# 0   45985289  47041434  47990761
# 1    9853972   9762546   9631482
# 2    3655437   3512547   3393191
# 3    2473990   2456016   2431774
# 4    2466338   2517680   2632035
# 5    1350948   1413644   1466143
# 6    1365961   1438551   1490158
# 7    1012110   1044934   1071673
# 8    8937752  10341006  11196053
# 9    1484536   1460770   1463650
# 10   1462621   1453872   1495984
# 11   1840410   1879417   2000473
# 12   1887239   1778879   1766044
# 13   1994287   1815174   1728749
# 14   2716218   2594719   2575370
# 15   2970929   3040993   3119571
# 16    512541    530686    528411
# 17       NaN       NaN       NaN

# %%
df2 = df2.reindex(index=[0, 1, 2, 3, 4, 5, 6, 7, 17, 8, 9, 10, 11, 12, 13, 14, 15, 16])

# %%
df2 = df2.reset_index()

# %%
df2 = df2.drop('index', axis=1)

# %%
df.iloc[:, 1:]
# Out:
#         2015      2020
# 0   51069375  51829136
# 1    9904312   9586195
# 2    3448737   3349016
# 3    2466052   2410700
# 4    2890451   2945454
# 5    1502881   1477573
# 6    1538394   1488435
# 7    1166615   1135423
# 8     204088    353933
# 9   12479061  13511676
# 10   1518040   1521763
# 11   1589347   1632088
# 12   2107802   2176636
# 13   1834114   1802766
# 14   1799044   1788807
# 15   2680294   2644757
# 16   3334524   3333056
# 17    605619    670858

# %%
new_df = pd.concat([df2, df.iloc[:, 1:]], axis=1)

# %%
new_df.replace(0, np.NaN, inplace=True)

# %%
new_df
# Out:
#       행정구역별      1970      1975      1980      1985      1990      1995  \
# 0        전국  31435252  34678972  37406815  40419652  43390374  44553710
# 1     서울특별시   5525262   6879464   8350616   9625755  10603250  10217177
# 2     부산광역시   1876391   2450125   3156931   3512113   3795892   3809618
# 3     대구광역시       NaN       NaN       NaN   2028370   2227979   2445288
# 4     인천광역시       NaN       NaN       NaN   1384916   1816328   2304176
# 5     광주광역시       NaN       NaN       NaN       NaN   1138717   1257063
# 6     대전광역시       NaN       NaN       NaN       NaN   1049122   1270873
# 7     울산광역시       NaN       NaN       NaN       NaN       NaN       NaN
# 8   세종특별자치시       NaN       NaN       NaN       NaN       NaN       NaN
# 9       경기도   3353272   4034707   4930335   4792617   6154359   7637942
# 10      강원도   1865426   1860768   1790226   1724146   1579859   1465279
# 11     충청북도   1480338   1521348   1423381   1390326   1389222   1395460
# 12     충청남도   2858202   2947023   2954662   2999837   2013270   1765021
# 13     전라북도   2431892   2455093   2286720   2201265   2069378   1900558
# 14     전라남도   4004832   3982752   3778777   3747506   2506944   2066109
# 15     경상북도   4555866   4855852   4952012   3010001   2860109   2672498
# 16     경상남도   3118634   3278718   3320546   3514500   3671509   3841553
# 17      제주도    365137    411486    462609    488300    514436    505095
#
#         2000      2005      2010      2015      2020
# 0   45985289  47041434  47990761  51069375  51829136
# 1    9853972   9762546   9631482   9904312   9586195
# 2    3655437   3512547   3393191   3448737   3349016
# 3    2473990   2456016   2431774   2466052   2410700
# 4    2466338   2517680   2632035   2890451   2945454
# 5    1350948   1413644   1466143   1502881   1477573
# 6    1365961   1438551   1490158   1538394   1488435
# 7    1012110   1044934   1071673   1166615   1135423
# 8        NaN       NaN       NaN    204088    353933
# 9    8937752  10341006  11196053  12479061  13511676
# 10   1484536   1460770   1463650   1518040   1521763
# 11   1462621   1453872   1495984   1589347   1632088
# 12   1840410   1879417   2000473   2107802   2176636
# 13   1887239   1778879   1766044   1834114   1802766
# 14   1994287   1815174   1728749   1799044   1788807
# 15   2716218   2594719   2575370   2680294   2644757
# 16   2970929   3040993   3119571   3334524   3333056
# 17    512541    530686    528411    605619    670858

# %%
# x = 연도
# y = 연도별 인구수
colors = list(mcolors.CSS4_COLORS.keys())
import random 
random.shuffle(colors) 

plt.figure(figsize=(15,10))
for i in range(1, 17):
    plt.plot(new_df.columns[1:], new_df.iloc[i, 1:].astype('float'), 
             label=new_df.iloc[i, 0], marker = 'o', linewidth = 1.5,
             color=colors[i],
            )
plt.legend()

# %% [markdown]
# ### 1인당 grdp

# %%
data_list
# Out:
# ['0.인구총조사_인구_시도_시_군_구.csv',
#  '1.총조사인구_총괄_시군구.csv',
#  '2.시도별_1인당_grdp.csv',
#  '3.시군구별 인구(05_19).csv',
#  '4.인구증가율_시도_시_군_구.csv',
#  '5.전입,전출(16_20,연별).csv',
#  '6.중위연령, 평균연령(00_19).csv']

# %%
df_grdp = pd.read_csv(os.path.join(data_dir, data_list[2]), encoding='cp949')

# %%
df_grdp
# Out:
#         시도별        1985        1990        1995    1995.1        2000  \
# 0       시도별  1인당 지역내총생산  1인당 지역내총생산  1인당 지역내총생산  1인당 민간소비  1인당 지역내총생산
# 1        전국        2245        4794        9871      5094       13952
# 2     서울특별시        2377        5086       10891      5702       16383
# 3     부산광역시        1932        3787        7024      5064        9790
# 4     대구광역시        1850        3819        6750      5229        9195
# 5     인천광역시        2743        5422        9839      4918       11875
# 6     광주광역시           -        4002        7759      5143        9862
# 7     대전광역시           -        4815        8167      4904       10982
# 8     울산광역시           -           -           -         -       29515
# 9   세종특별자치시           -           -           -         -           -
# 10      경기도        2707        5653       10154      5017       13374
# 11      강원도        2168        4577        8633      4688       11737
# 12     충청북도        2231        4474       10513      4547       13791
# 13     충청남도        1946        3802       10405      4592       17362
# 14     전라북도        1557        3237        7771      4644       10802
# 15     전라남도        1750        4013       10594      4807       15446
# 16     경상북도        2365        5238       10585      4976       16485
# 17     경상남도        2867        6110       12989      4803       14629
# 18  제주특별자치도        1669        3847        8598      4827       10971
#
#        2000.1    2000.2    2000.3        2005  ...    2010.2    2010.3  \
# 0   1인당 지역총소득  1인당 개인소득  1인당 민간소비  1인당 지역내총생산  ...  1인당 개인소득  1인당 민간소비
# 1       13860      8694      7571       19902  ...     14558     13503
# 2       17194      9978      8202       23151  ...     17277     16288
# 3       10933      8296      7567       14738  ...     13605     13145
# 4       10684      8274      7732       12809  ...     13446     12786
# 5       10633      7651      7248       17844  ...     13214     12449
# 6       10770      7969      7509       13904  ...     13439     13018
# 7       12425      8230      7424       15019  ...     14373     13257
# 8       25603     10271      7502       41016  ...     17634     13841
# 9           -         -         -           -  ...         -         -
# 10      14940      9142      7537       18082  ...     14455     13573
# 11      10791      7442      7289       16379  ...     12844     12045
# 12      11766      7694      7070       18923  ...     13246     11926
# 13      13203      8035      7153       27417  ...     13326     12183
# 14      10609      7684      7086       14920  ...     13197     11580
# 15      13171      7714      7254       23953  ...     13161     11659
# 16      13527      8116      7470       25286  ...     13342     11963
# 17      12784      8217      7138       21032  ...     13933     12357
# 18      11154      8259      7286       15599  ...     13259     12613
#
#           2015     2015.1    2015.2    2015.3        2019     2019.1  \
# 0   1인당 지역내총생산  1인당 지역총소득  1인당 개인소득  1인당 민간소비  1인당 지역내총생산  1인당 지역총소득
# 1        32556      32658     18063     15772       37274      37596
# 2        37236      41857     20857     18436       45118      48693
# 3        23956      25773     17044     15826       27577      29259
# 4        20991      24660     17226     15506       23883      27700
# 5        27798      28034     16598     14386       30584      32873
# 6        23139      25687     17459     15502       27799      31186
# 7        24094      27125     18229     15625       28561      31566
# 8        62605      49381     21348     16575       65112      54190
# 9        49474      44463     21957     17591       35802      38186
# 10       30748      33028     18069     15756       36064      38929
# 11       26946      24761     16311     14437       32192      29397
# 12       34728      28839     16531     14059       42704      34889
# 13       48173      35458     16703     14243       51874      41089
# 14       25621      24176     16239     14041       28835      28302
# 15       38339      32733     16067     13995       43402      35673
# 16       38510      32427     16550     14068       40082      35038
# 17       32007      29523     17411     14768       34040      32035
# 18       28280      27314     16685     15406       30792      30710
#
#       2019.2    2019.3
# 0   1인당 개인소득  1인당 민간소비
# 1      20661     18057
# 2      23978     21991
# 3      19723     18134
# 4      19196     17964
# 5      19582     16552
# 6      20791     18326
# 7      20648     18115
# 8      22617     18574
# 9      20674     16845
# 10     20746     17493
# 11     19174     16905
# 12     18989     15885
# 13     19216     16123
# 14     18941     16103
# 15     19072     16199
# 16     18748     16311
# 17     19078     16520
# 18     18815     17037
#
# [19 rows x 25 columns]

# %%
df_grdp.iloc[0, :].unique()
# Out:
# array(['시도별', '1인당 지역내총생산', '1인당 민간소비', '1인당 지역총소득', '1인당 개인소득'],
#       dtype=object)

# %%
list(range(1985, 2020, 5))
# Out:
# [1985, 1990, 1995, 2000, 2005, 2010, 2015]

# %%
years = ['시도별', '1985', '1990', '1995', '2000', '2005', '2010', '2015', '2019']
df_grdp_1 = df_grdp.loc[1:, years]

# %%
df_grdp_1 = df_grdp_1.replace('-', np.NaN)

# %%
## '1인당 지역내총생산' 시각화

colors=['#090707', '#E53A40', '#EFDC05', '#30A9DE', '#A593E0', '#E0E3DA', 
       '#566270', '#F6B352', '#8CD790', '#77AF9C', '#285943', '#58C9B9', 
        '#D499B9', '#f9c00c', '#00b9f1', '#7200da', '#a79c8e', '#cbe86b']


x = np.arange(len(years[1:]))

plt.figure(figsize=(15,10))
for i in range(0, 10):
    plt.bar(x+(0.1*i), df_grdp_1.iloc[i, 1:].astype('float'), 
             label=df_grdp_1.iloc[i, 0], 
             color = colors[i], width=0.05)    
plt.legend()
plt.xticks(x, years[1:])
# Out:
# ([<matplotlib.axis.XTick at 0x18c7c605c40>,
#   <matplotlib.axis.XTick at 0x18c7c605c10>,
#   <matplotlib.axis.XTick at 0x18c7c603790>,
#   <matplotlib.axis.XTick at 0x18c7c715d60>,
#   <matplotlib.axis.XTick at 0x18c7c71e2b0>,
#   <matplotlib.axis.XTick at 0x18c7c71e7c0>,
#   <matplotlib.axis.XTick at 0x18c7c71ecd0>,
#   <matplotlib.axis.XTick at 0x18c7c71e9d0>],
#  [Text(0, 0, '1985'),
#   Text(1, 0, '1990'),
#   Text(2, 0, '1995'),
#   Text(3, 0, '2000'),
#   Text(4, 0, '2005'),
#   Text(5, 0, '2010'),
#   Text(6, 0, '2015'),
#   Text(7, 0, '2019')])

# %%
new_df_1 = new_df.iloc[:, 4:]
# new_df_1

# %%
plt.figure(figsize=(15,10))
for i in range(1, 17):
    plt.plot(new_df.columns[1:], new_df.iloc[i, 1:].astype('float'), 
             label=new_df.iloc[i, 0], marker = 'o', linewidth = 1.5,
             color=colors[i],
            )
plt.legend()

# %% [markdown]
# ### grdp+인구 한 그래프에 그리기
# - grdp 데이터의 2019년과 인구데이터의 2020년을 동해 취급

# %%
df_grdp_2 = np.around(df_grdp_1.iloc[:, 1:].astype('float')*1000)

# %%
## '1인당 지역내총생산' 시각화

colors=['#090707', '#E53A40', '#EFDC05', '#30A9DE', '#A593E0', '#E0E3DA', 
       '#566270', '#F6B352', '#8CD790', '#77AF9C', '#285943', '#58C9B9', 
        '#D499B9', '#f9c00c', '#00b9f1', '#7200da', '#a79c8e', '#cbe86b']


x = np.arange(len(years[1:]))

plt.figure(figsize=(15,15))
for i in range(1, 10):
    plt.plot(x, new_df_1.iloc[i, :].astype('float'), 
             marker = 'o', linewidth = 1.5,
             color=colors[i],
            )
# for i in range(0, 10):
    plt.bar(x+(0.1*i), df_grdp_2.iloc[i, :].astype('float'), 
             label=df_grdp_1.iloc[i, 0], 
             color = colors[i], width=0.05)   
plt.legend()
plt.xticks(x, years[1:])
# Out:
# ([<matplotlib.axis.XTick at 0x18c7cb3db80>,
#   <matplotlib.axis.XTick at 0x18c7cb3db50>,
#   <matplotlib.axis.XTick at 0x18c7cb34670>,
#   <matplotlib.axis.XTick at 0x18c7ced9160>,
#   <matplotlib.axis.XTick at 0x18c7ced9670>,
#   <matplotlib.axis.XTick at 0x18c7ced9b80>,
#   <matplotlib.axis.XTick at 0x18c7ced9fa0>,
#   <matplotlib.axis.XTick at 0x18c7cedf0d0>],
#  [Text(0, 0, '1985'),
#   Text(1, 0, '1990'),
#   Text(2, 0, '1995'),
#   Text(3, 0, '2000'),
#   Text(4, 0, '2005'),
#   Text(5, 0, '2010'),
#   Text(6, 0, '2015'),
#   Text(7, 0, '2019')])

# %%
df_grdp_2 = np.around(df_grdp_1.iloc[:, 1:].astype('float'))
df_grdp_2 = df_grdp_2.reset_index()

# %%
df_grdp_2 = df_grdp_2.iloc[:, 1:]
df_grdp_2
# Out:
#       1985    1990     1995     2000     2005     2010     2015     2019
# 0   2245.0  4794.0   9871.0  13952.0  19902.0  26788.0  32556.0  37274.0
# 1   2377.0  5086.0  10891.0  16383.0  23151.0  31053.0  37236.0  45118.0
# 2   1932.0  3787.0   7024.0   9790.0  14738.0  19223.0  23956.0  27577.0
# 3   1850.0  3819.0   6750.0   9195.0  12809.0  16379.0  20991.0  23883.0
# 4   2743.0  5422.0   9839.0  11875.0  17844.0  23234.0  27798.0  30584.0
# 5      NaN  4002.0   7759.0   9862.0  13904.0  18667.0  23139.0  27799.0
# 6      NaN  4815.0   8167.0  10982.0  15019.0  19950.0  24094.0  28561.0
# 7      NaN     NaN      NaN  29515.0  41016.0  55585.0  62605.0  65112.0
# 8      NaN     NaN      NaN      NaN      NaN      NaN  49474.0  35802.0
# 9   2707.0  5653.0  10154.0  13374.0  18082.0  23972.0  30748.0  36064.0
# 10  2168.0  4577.0   8633.0  11737.0  16379.0  21312.0  26946.0  32192.0
# 11  2231.0  4474.0  10513.0  13791.0  18923.0  26455.0  34728.0  42704.0
# 12  1946.0  3802.0  10405.0  17362.0  27417.0  40962.0  48173.0  51874.0
# 13  1557.0  3237.0   7771.0  10802.0  14920.0  21016.0  25621.0  28835.0
# 14  1750.0  4013.0  10594.0  15446.0  23953.0  34768.0  38339.0  43402.0
# 15  2365.0  5238.0  10585.0  16485.0  25286.0  33341.0  38510.0  40082.0
# 16  2867.0  6110.0  12989.0  14629.0  21032.0  28026.0  32007.0  34040.0
# 17  1669.0  3847.0   8598.0  10971.0  15599.0  20366.0  28280.0  30792.0

# %%
for i in range(1, 8):
    df_grdp_2['mod_{}'.format(i)] = (df_grdp_2.iloc[:, i] - df_grdp_2.iloc[:,i-1]) / df_grdp_2.iloc[:, i-1]*100

# %%
# df_grdp_1 = df_grdp_1.reset_index()
df_grdp_1 = df_grdp_1.iloc[:, 1:]
df_grdp_1
# Out:
#     1985  1990   1995   2000   2005   2010   2015   2019
# 1   2245  4794   9871  13952  19902  26788  32556  37274
# 2   2377  5086  10891  16383  23151  31053  37236  45118
# 3   1932  3787   7024   9790  14738  19223  23956  27577
# 4   1850  3819   6750   9195  12809  16379  20991  23883
# 5   2743  5422   9839  11875  17844  23234  27798  30584
# 6    NaN  4002   7759   9862  13904  18667  23139  27799
# 7    NaN  4815   8167  10982  15019  19950  24094  28561
# 8    NaN   NaN    NaN  29515  41016  55585  62605  65112
# 9    NaN   NaN    NaN    NaN    NaN    NaN  49474  35802
# 10  2707  5653  10154  13374  18082  23972  30748  36064
# 11  2168  4577   8633  11737  16379  21312  26946  32192
# 12  2231  4474  10513  13791  18923  26455  34728  42704
# 13  1946  3802  10405  17362  27417  40962  48173  51874
# 14  1557  3237   7771  10802  14920  21016  25621  28835
# 15  1750  4013  10594  15446  23953  34768  38339  43402
# 16  2365  5238  10585  16485  25286  33341  38510  40082
# 17  2867  6110  12989  14629  21032  28026  32007  34040
# 18  1669  3847   8598  10971  15599  20366  28280  30792

# %%
df_mod = pd.concat([df_grdp_1.iloc[:, :1], df_grdp_2.iloc[:, 8:]], axis=1)

# %%
colors=['#090707', '#E53A40', '#EFDC05', '#30A9DE', '#A593E0', '#E0E3DA', 
       '#566270', '#F6B352', '#8CD790', '#77AF9C', '#285943', '#58C9B9', 
        '#D499B9', '#f9c00c', '#00b9f1', '#7200da', '#a79c8e', '#cbe86b']

plt.figure(figsize=(15,15))
for i in range(0, 18):
    plt.plot(df_mod.columns[1:], df_mod.iloc[i, 1:], color = colors[i], 
             label=df_mod.iloc[i, 0], marker = 'o', linewidth = 1.5,)
#     총인구수
#     plt.plot(x, new_df_1.iloc[i, 1:].astype('float'), 
#              marker = 'o', linewidth = 1.5,
#              color=colors[i],
#             )
    
plt.legend()

# %%
new_df_1
# Out:
#         1985      1990      1995      2000      2005      2010      2015  \
# 0   40419652  43390374  44553710  45985289  47041434  47990761  51069375
# 1    9625755  10603250  10217177   9853972   9762546   9631482   9904312
# 2    3512113   3795892   3809618   3655437   3512547   3393191   3448737
# 3    2028370   2227979   2445288   2473990   2456016   2431774   2466052
# 4    1384916   1816328   2304176   2466338   2517680   2632035   2890451
# 5        NaN   1138717   1257063   1350948   1413644   1466143   1502881
# 6        NaN   1049122   1270873   1365961   1438551   1490158   1538394
# 7        NaN       NaN       NaN   1012110   1044934   1071673   1166615
# 8        NaN       NaN       NaN       NaN       NaN       NaN    204088
# 9    4792617   6154359   7637942   8937752  10341006  11196053  12479061
# 10   1724146   1579859   1465279   1484536   1460770   1463650   1518040
# 11   1390326   1389222   1395460   1462621   1453872   1495984   1589347
# 12   2999837   2013270   1765021   1840410   1879417   2000473   2107802
# 13   2201265   2069378   1900558   1887239   1778879   1766044   1834114
# 14   3747506   2506944   2066109   1994287   1815174   1728749   1799044
# 15   3010001   2860109   2672498   2716218   2594719   2575370   2680294
# 16   3514500   3671509   3841553   2970929   3040993   3119571   3334524
# 17    488300    514436    505095    512541    530686    528411    605619
#
#         2020
# 0   51829136
# 1    9586195
# 2    3349016
# 3    2410700
# 4    2945454
# 5    1477573
# 6    1488435
# 7    1135423
# 8     353933
# 9   13511676
# 10   1521763
# 11   1632088
# 12   2176636
# 13   1802766
# 14   1788807
# 15   2644757
# 16   3333056
# 17    670858

# %%
new_df_1 = new_df_1.astype('float')

# %%
for i in range(1, 8):
    new_df_1['mod_{}'.format(i)] = (new_df_1.iloc[:, i] - new_df_1.iloc[:,i-1]) / new_df_1.iloc[:, i-1] *100

# %%
new_df_1
# Out:
#           1985        1990        1995        2000        2005        2010  \
# 0   40419652.0  43390374.0  44553710.0  45985289.0  47041434.0  47990761.0
# 1    9625755.0  10603250.0  10217177.0   9853972.0   9762546.0   9631482.0
# 2    3512113.0   3795892.0   3809618.0   3655437.0   3512547.0   3393191.0
# 3    2028370.0   2227979.0   2445288.0   2473990.0   2456016.0   2431774.0
# 4    1384916.0   1816328.0   2304176.0   2466338.0   2517680.0   2632035.0
# 5          NaN   1138717.0   1257063.0   1350948.0   1413644.0   1466143.0
# 6          NaN   1049122.0   1270873.0   1365961.0   1438551.0   1490158.0
# 7          NaN         NaN         NaN   1012110.0   1044934.0   1071673.0
# 8          NaN         NaN         NaN         NaN         NaN         NaN
# 9    4792617.0   6154359.0   7637942.0   8937752.0  10341006.0  11196053.0
# 10   1724146.0   1579859.0   1465279.0   1484536.0   1460770.0   1463650.0
# 11   1390326.0   1389222.0   1395460.0   1462621.0   1453872.0   1495984.0
# 12   2999837.0   2013270.0   1765021.0   1840410.0   1879417.0   2000473.0
# 13   2201265.0   2069378.0   1900558.0   1887239.0   1778879.0   1766044.0
# 14   3747506.0   2506944.0   2066109.0   1994287.0   1815174.0   1728749.0
# 15   3010001.0   2860109.0   2672498.0   2716218.0   2594719.0   2575370.0
# 16   3514500.0   3671509.0   3841553.0   2970929.0   3040993.0   3119571.0
# 17    488300.0    514436.0    505095.0    512541.0    530686.0    528411.0
#
#           2015        2020      mod_1      mod_2      mod_3      mod_4  \
# 0   51069375.0  51829136.0   7.349697   2.681092   3.213153   2.296702
# 1    9904312.0   9586195.0  10.154996  -3.641082  -3.554847  -0.927809
# 2    3448737.0   3349016.0   8.080008   0.361601  -4.047151  -3.908972
# 3    2466052.0   2410700.0   9.840857   9.753638   1.173768  -0.726519
# 4    2890451.0   2945454.0  31.150770  26.859025   7.037744   2.081710
# 5    1502881.0   1477573.0        NaN  10.392925   7.468599   4.640889
# 6    1538394.0   1488435.0        NaN  21.136817   7.482101   5.314207
# 7    1166615.0   1135423.0        NaN        NaN        NaN   3.243126
# 8     204088.0    353933.0        NaN        NaN        NaN        NaN
# 9   12479061.0  13511676.0  28.413328  24.106215  17.017804  15.700301
# 10   1518040.0   1521763.0  -8.368607  -7.252546   1.314221  -1.600904
# 11   1589347.0   1632088.0  -0.079406   0.449028   4.812822  -0.598173
# 12   2107802.0   2176636.0 -32.887354 -12.330636   4.271281   2.119473
# 13   1834114.0   1802766.0  -5.991419  -8.158007  -0.700794  -5.741721
# 14   1799044.0   1788807.0 -33.103669 -17.584557  -3.476196  -8.981305
# 15   2680294.0   2644757.0  -4.979799  -6.559575   1.635923  -4.473095
# 16   3334524.0   3333056.0   4.467463   4.631447 -22.663334   2.358320
# 17    605619.0    670858.0   5.352447  -1.815775   1.474178   3.540205
#
#        mod_5      mod_6      mod_7
# 0   2.018066   6.415014   1.487704
# 1  -1.342519   2.832690  -3.211904
# 2  -3.397990   1.636984  -2.891522
# 3  -0.987046   1.409588  -2.244559
# 4   4.542078   9.818107   1.902921
# 5   3.713736   2.505758  -1.683966
# 6   3.587429   3.236972  -3.247478
# 7   2.558918   8.859232  -2.673718
# 8        NaN        NaN  73.421759
# 9   8.268509  11.459467   8.274781
# 10  0.197156   3.716052   0.245250
# 11  2.896541   6.240909   2.689218
# 12  6.441146   5.365181   3.265677
# 13 -0.721522   3.854377  -1.709163
# 14 -4.761252   4.066235  -0.569024
# 15 -0.745707   4.074133  -1.325862
# 16  2.583959   6.890467  -0.044024
# 17 -0.428690  14.611354  10.772284

# %%
new_df
# Out:
#       행정구역별      1970      1975      1980      1985      1990      1995  \
# 0        전국  31435252  34678972  37406815  40419652  43390374  44553710
# 1     서울특별시   5525262   6879464   8350616   9625755  10603250  10217177
# 2     부산광역시   1876391   2450125   3156931   3512113   3795892   3809618
# 3     대구광역시       NaN       NaN       NaN   2028370   2227979   2445288
# 4     인천광역시       NaN       NaN       NaN   1384916   1816328   2304176
# 5     광주광역시       NaN       NaN       NaN       NaN   1138717   1257063
# 6     대전광역시       NaN       NaN       NaN       NaN   1049122   1270873
# 7     울산광역시       NaN       NaN       NaN       NaN       NaN       NaN
# 8   세종특별자치시       NaN       NaN       NaN       NaN       NaN       NaN
# 9       경기도   3353272   4034707   4930335   4792617   6154359   7637942
# 10      강원도   1865426   1860768   1790226   1724146   1579859   1465279
# 11     충청북도   1480338   1521348   1423381   1390326   1389222   1395460
# 12     충청남도   2858202   2947023   2954662   2999837   2013270   1765021
# 13     전라북도   2431892   2455093   2286720   2201265   2069378   1900558
# 14     전라남도   4004832   3982752   3778777   3747506   2506944   2066109
# 15     경상북도   4555866   4855852   4952012   3010001   2860109   2672498
# 16     경상남도   3118634   3278718   3320546   3514500   3671509   3841553
# 17      제주도    365137    411486    462609    488300    514436    505095
#
#         2000      2005      2010      2015      2020
# 0   45985289  47041434  47990761  51069375  51829136
# 1    9853972   9762546   9631482   9904312   9586195
# 2    3655437   3512547   3393191   3448737   3349016
# 3    2473990   2456016   2431774   2466052   2410700
# 4    2466338   2517680   2632035   2890451   2945454
# 5    1350948   1413644   1466143   1502881   1477573
# 6    1365961   1438551   1490158   1538394   1488435
# 7    1012110   1044934   1071673   1166615   1135423
# 8        NaN       NaN       NaN    204088    353933
# 9    8937752  10341006  11196053  12479061  13511676
# 10   1484536   1460770   1463650   1518040   1521763
# 11   1462621   1453872   1495984   1589347   1632088
# 12   1840410   1879417   2000473   2107802   2176636
# 13   1887239   1778879   1766044   1834114   1802766
# 14   1994287   1815174   1728749   1799044   1788807
# 15   2716218   2594719   2575370   2680294   2644757
# 16   2970929   3040993   3119571   3334524   3333056
# 17    512541    530686    528411    605619    670858

# %%
plt.plot(df_mod.columns[1:], df_grdp_2.loc[9, 'mod_1':])

# %%
### 경기도 인구, grdp 

x = np.arange(len(df_mod.columns[1:]))
plt.figure(figsize=(15,10))

plt.plot(new_df_1.columns[1:8], new_df.loc[9, '1990':].astype('float'), label='인구수')
plt.plot(df_mod.columns[1:], df_grdp_2.loc[9, 'mod_1':]*1000, 
          label='grdp', marker = 'o', linewidth = 1.5)
plt.legend()

# %% [markdown]
# ### 지도 시각화

# %%
df_hi

# %%
# Initialize the map:
m = folium.Map(location=[36, 127], tiles="OpenStreetMap", zoom_start=7)

choropleth = folium.Choropleth(
    geo_data=str(geojson_path / state_geo),
    name='인구수',
    data=df_drop,
    columns=['행정구역별(읍면동)', '2015'],
    key_on='feature.properties.CTP_KOR_NM',
    fill_color='YlOrRd',
    fill_opacity=0.7,
    line_opacity=0.3,
    color = 'gray',
    legend_name = 'Population'
).add_to(m)

choropleth.geojson.add_child(folium.features.GeoJsonTooltip(['CTP_KOR_NM'], labels=False))
title_html = '<h3 align="center" style="font-size:20px"><b>people index </b></h3>'
m.get_root().html.add_child(folium.Element(title_html))
folium.LayerControl().add_to(m)

# Save to html
# m.save('folium_kr.html')

m
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-51-9c9575293bea> in <module>
#       1 # Initialize the map:
# ----> 2 m = folium.Map(location=[36, 127], tiles="OpenStreetMap", zoom_start=7)
#       3
#       4 choropleth = folium.Choropleth(
#       5     geo_data=str(geojson_path / state_geo),
#
# NameError: name 'folium' is not defined
